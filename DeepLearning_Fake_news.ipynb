# %% [markdown]
# <a href="https://colab.research.google.com/github/shalinitiwarigit/Fake-news-deepLearning/blob/main/DeepLearning_Fake_news.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/fake_and_real_news.csv')

# %%
df.head()
# Out:
#                                                 Text label
# 0   Top Trump Surrogate BRUTALLY Stabs Him In The...  Fake
# 1  U.S. conservative leader optimistic of common ...  Real
# 2  Trump proposes U.S. tax overhaul, stirs concer...  Real
# 3   Court Forces Ohio To Allow Millions Of Illega...  Fake
# 4  Democrats say Trump agrees to work on immigrat...  Real

# %%
df.rename(columns={'label':'target'},inplace=True)

# %%
df.head()
# Out:
#                                                 Text target
# 0   Top Trump Surrogate BRUTALLY Stabs Him In The...   Fake
# 1  U.S. conservative leader optimistic of common ...   Real
# 2  Trump proposes U.S. tax overhaul, stirs concer...   Real
# 3   Court Forces Ohio To Allow Millions Of Illega...   Fake
# 4  Democrats say Trump agrees to work on immigrat...   Real

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df['target']=le.fit_transform(df['target'])

# %%
df.head()
# Out:
#                                                 Text  target
# 0   Top Trump Surrogate BRUTALLY Stabs Him In The...       0
# 1  U.S. conservative leader optimistic of common ...       1
# 2  Trump proposes U.S. tax overhaul, stirs concer...       1
# 3   Court Forces Ohio To Allow Millions Of Illega...       0
# 4  Democrats say Trump agrees to work on immigrat...       1

# %%
df['target'].value_counts()
# Out:
# target
# 0    5000
# 1    4900
# Name: count, dtype: int64

# %%
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
ps=PorterStemmer()

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import nltk

# Correct downloads
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def transform_text(text):
  text=text.lower()
  text=nltk.word_tokenize(text)
  y=[]
  for i in text:

      if i.isalnum():
         y.append(i)
  text=y[:]
  y.clear()
  for i in text:
    if i not in stopwords.words('english') and i not in string.punctuation:
      y.append(i)

  text=y[:]
  y.clear()

  for i in text:
    y.append(ps.stem(i))


  return " ".join(y)

# %%
transform_text("SHALINI TiwaRI?? j4 dancing")
# Out:
# 'shalini tiwari j4 danc'

# %%
df["Text"]=df['Text'].apply(transform_text)

# %%
df.head()
# Out:
#                                                 Text  target
# 0  top trump surrog brutal stab back pathet video...       0
# 1  conserv leader optimist common ground healthca...       1
# 2  trump propos tax overhaul stir concern deficit...       1
# 3  court forc ohio allow million illeg purg voter...       0
# 4  democrat say trump agre work immigr bill wall ...       1

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
tfidf=TfidfVectorizer()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Initialize TF-IDF
tfidf = TfidfVectorizer(max_features=5000)  # limit features for ANN

# Fit and transform text
X = tfidf.fit_transform(df['Text']).toarray()  # X will be a NumPy array

# %%
y=df['target'].values

# %%
y
# Out:
# array([0, 1, 1, ..., 1, 0, 0])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

input_dim = X_train.shape[1]  # number of features

model = Sequential()
model.add(Dense(128, input_dim=input_dim, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(1, activation='sigmoid'))  # binary classification

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
history = model.fit(
    X_train, y_train,
    epochs=10,
    batch_size=32,
    validation_split=0.2
)
# Out:
# Epoch 1/10
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.8671 - loss: 0.3729 - val_accuracy: 0.9937 - val_loss: 0.0234
# Epoch 2/10
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9982 - loss: 0.0100 - val_accuracy: 0.9949 - val_loss: 0.0186
# Epoch 3/10
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9949 - val_loss: 0.0179
# Epoch 4/10
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 1.0000 - loss: 6.4939e-04 - val_accuracy: 0.9949 - val_loss: 0.0178
# Epoch 5/10
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 1.0000 - loss: 5.4572e-04 - val_accuracy: 0.9956 - val_loss: 0.0179
# Epoch 6/10
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 1.0000 - loss: 2.4103e-04 - val_accuracy: 0.9962 - val_loss: 0.0180
# Epoch 7/10
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 1.0000 - loss: 2.3509e-04 - val_accuracy: 0.9949 - val_loss: 0.0176
# Epoch 8/10
# ...

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print("Test Accuracy:", accuracy)
# Out:
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9953 - loss: 0.0159
# Test Accuracy: 0.9939393997192383
